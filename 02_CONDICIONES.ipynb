# %% [markdown]
# # CONDICIONES

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
not(True)
# Out:
# False

# %%
5>2
# Out:
# True

# %%
5<2
# Out:
# False

# %%
5==5
# Out:
# True

# %%
if 5>2:
    print("5 es mayor que 2")
else:
    print("2 no es mayor que 5")
# Out:
# 5 es mayor que 2

# %%
def par_impar(valor):
    if  valor%2==0:
        print(f"{valor} es par")
    else:
        print(f"{valor} no es par")

# %%
par_impar(2)
# Out:
# 2 es par

# %%
import math

# %%
def raiz_cuadrada(valor):
    r=math.sqrt(valor)
    return r

# %%
r1= raiz_cuadrada(4)
print(r1)
# Out:
# 2.0

# %%
r2= raiz_cuadrada(3)
print(r2)
# Out:
# 1.7320508075688772
