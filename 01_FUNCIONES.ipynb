# %%
def sumar_numeros(a,b):
    suma=a+b
    return suma

# %%
S1 = sumar_numeros(3,2)
print (S1)
# Out:
# 5

# %%
S2 = sumar_numeros(10,12)
print (S2)
# Out:
# 22

# %%
def imprimir(valor):
    print (f"El valor es {valor}")

# %%
imprimir (5)
# Out:
# El valor es 5

# %%
r=sumar_numeros(S1,S2)
imprimir(r)
# Out:
# El valor es 27
